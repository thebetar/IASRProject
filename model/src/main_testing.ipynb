# %% [markdown]
# IMPORT LIBRARIES

# %%
# Import libraries
import os
import librosa
import csv
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import argrelextrema
import sounddevice as sd
from sklearn.model_selection import train_test_split
from sklearn import metrics
from tqdm import tqdm
from random import shuffle
from IPython.display import clear_output

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %% [markdown]
# TASK 1: Read wav files and create numpy array of them

# %% [markdown]
#     TASK 1.1 Get voiced parts

# %%
def get_auto_correlation(clip, FRAME_SIZE = 100):
    bins = np.zeros(FRAME_SIZE)
    for i in range(0, FRAME_SIZE):
        for j in range(0, FRAME_SIZE-i):
            bins[i] += (clip[j] * clip[j+i])
    return bins

#doesnt work perfectly - it doesnt connect all parts of audio
def get_voiced_parts(clip, sr, FRAME_SIZE = 100):
    IS_CURR_VOICED = False

    MAX_NUM_FRAMES = 25
    START_NUM_FRAMES = 20
    MIN_NUM_OF_SAMPLES_IN_SEGMENT = 0.2 * sr
    MIN_RMS = 0.05

    voiced_counter = 0
    start_of_segment = -1
    end_of_segment = -1
    end_of_checking = (len(clip)//FRAME_SIZE-1) * FRAME_SIZE

    for i in range(0, end_of_checking, FRAME_SIZE):
        #for each frame
        bins = np.zeros(FRAME_SIZE)
        bins = get_auto_correlation(clip[i:i+FRAME_SIZE], FRAME_SIZE)
        #plt.stem(bins)
        maximums = np.diff(argrelextrema(bins, np.greater))
        median_maximums = np.median(maximums)
        #if median maximus in some boudaries
        if median_maximums >= 7 and median_maximums <= 20 and np.std(maximums) < 7:
            voiced_counter = min(voiced_counter + 1, MAX_NUM_FRAMES)

            if not IS_CURR_VOICED:
                voiced_counter = START_NUM_FRAMES
                IS_CURR_VOICED = True
                start_of_segment = i
        else:
            voiced_counter = max(0, voiced_counter - 1)

            if voiced_counter == 0 and IS_CURR_VOICED:
                IS_CURR_VOICED = False
                end_of_segment = i
                #if too short
                if end_of_segment - start_of_segment < MIN_NUM_OF_SAMPLES_IN_SEGMENT:
                    continue 
                rms = np.sqrt(np.mean(clip[start_of_segment:end_of_segment]**2))
                if rms < MIN_RMS:
                    continue
                return clip[start_of_segment: end_of_segment]

    end_of_segment = len(clip)
    
    if IS_CURR_VOICED and ((end_of_segment - start_of_segment) > MIN_NUM_OF_SAMPLES_IN_SEGMENT):
        return clip[start_of_segment: end_of_segment]       
    return None

# %%
#trying to detect spoken parts with outocorrleation
new_sr = 8000
clip, sr = librosa.load("../data/six/anja_3.wav")
clip = librosa.resample(clip, orig_sr=sr, target_sr=new_sr)
clip = librosa.to_mono(clip)
clip = librosa.util.normalize(clip)

plt.plot(get_auto_correlation(clip[:100]))

# %% [markdown]
# TESTING !!!!

# %%
#trying to detect spoken parts with outocorrleation
new_sr = 8000
clip, sr = librosa.load("../data/six/anja_3.wav")
clip = librosa.resample(clip, orig_sr=sr, target_sr=new_sr)
clip = librosa.to_mono(clip)
clip = librosa.util.normalize(clip)

IS_CURR_VOICED = False

MAX_NUM_FRAMES = 25
START_NUM_FRAMES = 20
MIN_NUM_OF_SAMPLES_IN_SEGMENT = 0.2 * new_sr
MIN_RMS = 0.05

voiced_counter = 0
start_of_segment = -1
end_of_segment = -1
FRAME_SIZE = 100
len_clip_in_frames = len(clip) // FRAME_SIZE - 1
end_of_checking = len_clip_in_frames * FRAME_SIZE
out = np.zeros(len_clip_in_frames)
curr_voiced_over_time = np.zeros(len_clip_in_frames)

for i in range(0, end_of_checking, FRAME_SIZE):
    #for each frame
    bins = np.zeros(FRAME_SIZE)
    bins = get_auto_correlation(clip[i:i+FRAME_SIZE], FRAME_SIZE)
    #plt.stem(bins)
    maximums = np.diff(argrelextrema(bins, np.greater))
    median_maximums = np.median(maximums)
    #if median maximus in some boudaries
    if median_maximums >= 7 and median_maximums <= 20 and np.std(maximums) < 7:
        out[i//FRAME_SIZE] = 1
        voiced_counter = min(voiced_counter + 1,MAX_NUM_FRAMES)
        if  not IS_CURR_VOICED:
            voiced_counter = START_NUM_FRAMES
            IS_CURR_VOICED = True
            start_of_segment = i
    else:
        voiced_counter = max(0, voiced_counter-1)

        if voiced_counter == 0 and IS_CURR_VOICED:
            IS_CURR_VOICED = False
            end_of_segment = i
            #if too short
            if end_of_segment - start_of_segment < MIN_NUM_OF_SAMPLES_IN_SEGMENT:
                continue

            rms = np.sqrt(np.mean(clip[start_of_segment:end_of_segment]**2))
            if rms < MIN_RMS:
                continue

            a = clip[start_of_segment: end_of_segment]
            print(start_of_segment/new_sr, end_of_segment/new_sr)
            plt.axvline(start_of_segment, color='g')
            plt.axvline(end_of_segment, color='g')

    #plt.show() 

    curr_voiced_over_time[i//FRAME_SIZE] = voiced_counter
end_of_segment = len(clip)
if IS_CURR_VOICED and ((end_of_segment - start_of_segment) > MIN_NUM_OF_SAMPLES_IN_SEGMENT):
    plt.axvline(start_of_segment, color='g')
    plt.axvline(end_of_segment, color='g')
    print(end_of_segment - start_of_segment)
#print(start_of_segment/new_sr, end_of_segment/new_sr)
plt.stem(np.repeat(out, FRAME_SIZE)*0.5, 'r')
plt.plot(clip)

plt.plot(np.repeat(curr_voiced_over_time, FRAME_SIZE)*0.1, 'k')
sd.play(a, 8000)
#print(maximums)
#plt.plot(clip)
# Out:
# /home/larsvonk/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/larsvonk/.local/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 7660
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 72
#      69 plt.plot(clip)
#      71 plt.plot(np.repeat(curr_voiced_over_time, FRAME_SIZE)*0.1, 'k')
# ---> 72 sd.play(a, 8000)
#      73 #print(maximums)
#      74 #plt.plot(clip)
#
# File ~/.local/lib/python3.10/site-packages/sounddevice.py:167, in play(data, samplerate, mapping, blocking, loop, **kwargs)
#     100 """Play back a NumPy array containing audio data.
#     101
#     102 This is a convenience function for interactive use and for small
#    (...)
#     164
#     165 """
#     166 ctx = _CallbackContext(loop=loop)
# --> 167 ctx.frames = ctx.check_data(data, mapping, kwargs.get('device'))
#     169 def callback(outdata, frames, time, status):
#     170     assert len(outdata) == frames
#
# File ~/.local/lib/python3.10/site-packages/sounddevice.py:2478, in _CallbackContext.check_data(self, data, mapping, device)
#    2475     raise ValueError(
#    2476         'audio data to be played back must be one- or two-dimensional')
#    2477 frames, channels = data.shape
# -> 2478 dtype = _check_dtype(data.dtype)
#    2479 mapping_is_explicit = mapping is not None
#    2480 mapping, channels = _check_mapping(mapping, channels)
#
# File ~/.local/lib/python3.10/site-packages/sounddevice.py:2638, in _check_dtype(dtype)
#    2636     dtype = 'float32'
#    2637 else:
# -> 2638     raise TypeError('Unsupported data type: ' + repr(dtype))
#    2639 return dtype
#
# TypeError: Unsupported data type: 'object'

# %% [markdown]
#     TASK 1.2 Normalize between -1 and 1

# %% [markdown]
# TASK 2. FEATURE EXTRACTION

# %% [markdown]
#     TASK 2.1 Preemphasis filter

# %%
def add_preemphasis_filter(x, coeff=0.95):
    x = librosa.effects.preemphasis(x, coef = coeff)
    return x

# %% [markdown]
#     TASK 2.2 Create MFCC of samles of uniform size (30, 80)

# %%
def get_2d_features(y, sr = 8000, wanted_width = 40):
    y = add_preemphasis_filter(y)
    #20 row mfcc, 20 row delta mfcc, 1 row pitch...
    windows_size = len(y) // (wanted_width - 1)
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mels=20, n_fft=300, hop_length=windows_size, window='hamming')
    delta_mfcc = librosa.feature.delta(mfcc)
    mfcc = np.concatenate((mfcc, delta_mfcc, ), axis=0)
    return mfcc

# %%
def get_1d_features(y, sr = 8000, wanted_width = 5):
    windows_size = len(y)//(wanted_width - 1)
    #coeffients of polynomial fitting frequency information over time
    polly_coeff = librosa.feature.poly_features(y=y, sr=sr, order=0, n_fft=1024, hop_length=windows_size, window='hamming')[0]
    #how many times do signal cross zero
    zero_cross = librosa.feature.zero_crossing_rate(y=y, frame_length=1024, hop_length=windows_size)[0]
    #tone vs noise level in each windows
    tone_vs_noise = librosa.feature.spectral_flatness(y=y, n_fft=1024, hop_length=windows_size)[0]
    
    return np.concatenate((polly_coeff, zero_cross, tone_vs_noise), axis=0)

# %% [markdown]
#         TESTING!

# %%
new_sr = 8000
clip, sr = librosa.load("../data/eight/luka_3.wav")
clip = librosa.resample(clip, orig_sr=sr, target_sr=new_sr)
clip = librosa.to_mono(clip)
clip = librosa.util.normalize(clip)
clip = get_voiced_parts(clip, new_sr)
clip = add_preemphasis_filter(clip)
features = get_2d_features(clip, new_sr)


print(get_1d_features(clip))

sd.play(clip, new_sr)
sd.wait()
plt.plot(clip)
plt.show()
plt.imshow(features, cmap='hot', interpolation='nearest')
# Out:
# /home/larsvonk/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/larsvonk/.local/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# [1.96106221 2.7488533  0.65854726 0.09661637 0.32039525 0.22558594
#  0.5        0.52734375 0.59082031 0.30566406 0.14811699 0.03635823
#  0.0411064  0.3276951  0.31542945]

# %% [markdown]
#     TASK 2.3 Other feutures -TODO

# %% [markdown]
# Here we see the example main function to create train/validate and test set

# %%
def make_train_data(directory):
    training_data = []
    labels = []
    eye_in = 0
    NUM_CATEGORIES = len(os.listdir(directory))-2#TODO MAKE THIS BETTER
    #get all subdirectories in directory
    for category in os.listdir(directory):
        if category[0] == '.':
            print("skipping {}".format(category))
            continue
        print(category)
        labels.append(category)
        path = os.path.join(directory, category)
        for file in os.listdir(path):
            try:
                #Fs, audio = wavfile.read(os.path.join(path, file))
                clip, sr = librosa.load(os.path.join(path, file))
                clip = librosa.resample(clip, orig_sr=sr, target_sr=8000)
                clip = librosa.to_mono(clip)

                clip = librosa.util.normalize(clip)
                clip = get_voiced_parts(clip,8000)

                if(clip is None):
                    print("{} not good".format(os.path.join(path, file)))
                    continue

                features_2d = get_2d_features(clip)
                features_1d = get_1d_features(clip)

                training_data.append([features_2d, features_1d, np.eye(NUM_CATEGORIES)[eye_in]])
            except Exception as e:
                print(e)
                pass
        eye_in += 1
    np.random.shuffle(training_data)
    training_data = np.array(training_data, dtype=object)

    # Split the features and labels
    X_2d = np.array([i[0] for i in training_data])
    X_1d = np.array([i[1] for i in training_data])
    y = np.array([i[2] for i in training_data])

    # Split the data into training and test sets
    X_2d_train, X_2d_test, X_1d_train, X_1d_test, y_train, y_test = train_test_split(X_2d, X_1d, y, test_size=0.15, random_state=42)

    return np.array(labels), X_2d_train, X_2d_test, X_1d_train, X_1d_test, y_train, y_test

#X_2d_train, X_2d_test, X_1d_train, X_1d_test, y_train, y_test = make_train_data(os.path.join(os.getcwd(), "..", "data"))

# %% [markdown]
# Train reduced data

# %%
labels, X_2d_train, X_2d_test, X_1d_train, X_1d_test, y_train, y_test = make_train_data(os.path.join(os.getcwd(), "..", "reduced_data"))

np.savez("training_data_reduced.npz", labels=labels, X_2d_train=X_2d_train, X_2d_test=X_2d_test, X_1d_train=X_1d_train, X_1d_test=X_1d_test, y_train=y_train, y_test=y_test)

# %% [markdown]
# Train all data

# %%
labels, X_2d_train, X_2d_test, X_1d_train, X_1d_test, y_train, y_test = make_train_data(os.path.join(os.getcwd(), "..", "data"))

np.savez("training_data.npz", labels=labels, X_2d_train=X_2d_train, X_2d_test=X_2d_test, X_1d_train=X_1d_train, X_1d_test=X_1d_test, y_train=y_train, y_test=y_test)
# Out:
# skipping .divide
# skipping .multiply
# eight
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\eight\ nicolas_0.wav not good
# d:\Anaconda\envs\IASR\Lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# d:\Anaconda\envs\IASR\Lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\eight\ theo_40.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\eight\ theo_42.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\eight\ yweweler_17.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\eight\ yweweler_19.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\eight\ yweweler_42.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\eight\ yweweler_43.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\eight\ yweweler_49.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\eight\aditya_3.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\eight\aditya_5.wav not good
# five
# four
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\four\ yweweler_8.wav not good
# minus
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\minus\ curi_03.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\minus\ curi_26.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\minus\ curi_44.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\minus\ wengie_33.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\minus\minus-Yuhan-2.wav not good
# nine
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\nine\ theo_2.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\nine\ theo_45.wav not good
# one
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\one\ theo_1.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\one\ theo_2.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\one\ theo_4.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\one\ theo_41.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\one\ theo_45.wav not good
# over
# plus
# seven
# six
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ nicolas_0.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ nicolas_1.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ nicolas_15.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ nicolas_16.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ nicolas_17.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ nicolas_18.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ nicolas_19.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ nicolas_2.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ nicolas_20.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ nicolas_21.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ nicolas_22.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ nicolas_23.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ nicolas_26.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ nicolas_28.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ nicolas_29.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ nicolas_34.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ nicolas_35.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ nicolas_36.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ nicolas_37.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ nicolas_38.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ nicolas_39.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ nicolas_40.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ nicolas_41.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ nicolas_42.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ nicolas_45.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ nicolas_48.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ nicolas_5.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ nicolas_6.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ nicolas_7.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ nicolas_9.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ yweweler_1.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ yweweler_10.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ yweweler_17.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ yweweler_19.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ yweweler_2.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ yweweler_20.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ yweweler_23.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ yweweler_24.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ yweweler_25.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ yweweler_26.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ yweweler_27.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ yweweler_3.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ yweweler_32.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ yweweler_35.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ yweweler_36.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ yweweler_4.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ yweweler_42.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ yweweler_44.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ yweweler_46.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ yweweler_47.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\six\ yweweler_8.wav not good
# three
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ jackson_5.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ jackson_6.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ nicolas_10.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ nicolas_11.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ nicolas_13.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ nicolas_14.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ nicolas_16.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ nicolas_17.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ nicolas_18.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ nicolas_19.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ nicolas_2.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ nicolas_20.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ nicolas_22.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ nicolas_26.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ nicolas_28.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ nicolas_3.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ nicolas_30.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ nicolas_31.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ nicolas_32.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ nicolas_35.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ nicolas_36.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ nicolas_37.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ nicolas_38.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ nicolas_39.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ nicolas_4.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ nicolas_40.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ nicolas_41.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ nicolas_43.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ nicolas_44.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ nicolas_45.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ nicolas_47.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ nicolas_48.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ nicolas_5.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ nicolas_6.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ nicolas_7.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ nicolas_8.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ theo_0.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ theo_1.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ theo_10.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ theo_11.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ theo_12.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ theo_16.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ theo_17.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ theo_19.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ theo_3.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ theo_34.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ theo_4.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ theo_44.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ theo_5.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ theo_6.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ theo_8.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ yweweler_31.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ yweweler_38.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\ yweweler_8.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\three\aditya_1.wav not good
# times
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\times\ wengie_05.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\times\ wengie_10.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\times\ wengie_16.wav not good
# two
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ jackson_10.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ jackson_12.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ jackson_23.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ jackson_26.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ jackson_27.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ jackson_30.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ jackson_31.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ jackson_32.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ jackson_35.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ jackson_4.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ jackson_43.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ jackson_46.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ jackson_7.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ jackson_9.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_0.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_1.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_10.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_11.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_12.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_13.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_14.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_15.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_16.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_17.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_18.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_2.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_20.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_21.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_22.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_23.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_24.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_25.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_26.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_27.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_28.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_29.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_3.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_30.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_31.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_32.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_33.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_35.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_36.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_37.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_38.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_39.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_4.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_40.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_41.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_43.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_44.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_45.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_46.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_47.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_48.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_49.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_5.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_6.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_7.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ nicolas_9.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ theo_0.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ theo_1.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ theo_10.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ theo_11.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ theo_12.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ theo_13.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ theo_14.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ theo_15.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ theo_18.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ theo_24.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ theo_25.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ theo_27.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ theo_3.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ theo_30.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ theo_32.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ theo_34.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ theo_35.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ theo_36.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ theo_37.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ theo_39.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ theo_4.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ theo_40.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ theo_41.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ theo_42.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ theo_43.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ theo_44.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ theo_45.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ theo_46.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ theo_47.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ theo_48.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ theo_49.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ theo_5.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ theo_6.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ theo_7.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ theo_8.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ theo_9.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ yweweler_10.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ yweweler_19.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ yweweler_2.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ yweweler_20.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ yweweler_24.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ yweweler_25.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ yweweler_3.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ yweweler_31.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ yweweler_47.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\ yweweler_8.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\luka_3.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\two\luka_4.wav not good
# zero
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\zero\ nicolas_38.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\zero\ theo_32.wav not good
# d:\Faks\5\ERASMUS\ImageAndSpeechRecognition\Project\IASRProject\src\..\data\zero\ theo_48.wav not good

# %% [markdown]
# Task 3. Neural network

# %%
#Load reduced set
labels, X_2d_train, X_2d_test, X_1d_train,  X_1d_test, y_train,y_test = np.load("training_data_reduced.npz", allow_pickle=True).values()

# %%
#Load whole set
labels, X_2d_train, X_2d_test, X_1d_train,  X_1d_test, y_train,y_test = np.load("training_data_2.npz", allow_pickle=True).values()

# %%
print(y_train.shape)
print(X_2d_train.shape)
print(X_1d_train.shape)

print(y_test.shape)
print(X_2d_test.shape)
print(X_1d_test.shape)
print(labels)
print(len(labels))
# Out:
# (2290, 14)
# (2290, 40, 40)
# (2290, 15)
# (405, 14)
# (405, 40, 40)
# (405, 15)
# ['eight' 'five' 'four' 'minus' 'nine' 'one' 'over' 'plus' 'seven' 'six'
#  'three' 'times' 'two' 'zero']
# 14

# %% [markdown]
#  Example show of random feature vector

# %%
# Features from mfcc
## Index of sample to observe
INDEX = 2

## MFCC features
plt.imshow(X_2d_train[INDEX][:20])
plt.show()

## Delta MFCC features
plt.imshow(X_2d_train[INDEX][21:])
plt.show()

## Logarithmic MFCC features
plt.imshow(np.log10(X_2d_train[INDEX]))
plt.show()
print(X_1d_train[INDEX])
print(labels[np.argmax(y_test[INDEX])])
# Out:
# [2.29320907 1.58856524 1.27018921 1.15321085 0.48267148 0.05273438
#  0.10449219 0.109375   0.17285156 0.11621094 0.02455604 0.0064328
#  0.00713394 0.01455325 0.06195601]
# four

# %%
# Define the missing variables
height = 40
width = 40
number_of_linear_values = 15
number_of_classes = len(labels)

class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 20, 5)
        self.conv2 = nn.Conv2d(20, 30, 3)
        self.conv3_bn = nn.BatchNorm2d(30)

        x = torch.randn(height,width).view(-1,1,height,width)
        self._to_linear = None
        self.convs(x)

        self.fc1 = nn.Linear(self._to_linear + number_of_linear_values, 256)
        self.dropout2 = nn.Dropout(0.2)
        self.fc1_bn = nn.BatchNorm1d(256)
        self.fc2 = nn.Linear(256, number_of_classes) # Adjusted to match the number of classes

    def convs(self, x):
        x = F.max_pool2d(F.leaky_relu(self.conv1(x)), (2,2))
        x = F.max_pool2d(F.leaky_relu(self.conv3_bn(self.conv2(x))), (2, 2))

        if self._to_linear is None:
            self._to_linear = x[0].shape[0]*x[0].shape[1]*x[0].shape[2]
        return x

    def forward(self, data_2d, data_1d):
        data_2d = self.convs(data_2d)
        #now new data is added to linear layers
        data_2d = data_2d.view(-1, self._to_linear)
        x = torch.cat((data_2d , data_1d), dim=1)
        x = F.leaky_relu(self.fc1_bn(self.fc1(x)))
        x = self.dropout2(x)
        x = self.fc2(x)
        return F.softmax(x, dim=1)

# %%
device = torch.device("cpu")

# %%
if torch.cuda.is_available():
    device = torch.device("cuda:0")
    print("GPU")
else:
    device = torch.device("cpu")
    print("CPU")
    
os.environ['CUDA_VISIBLE_DEVICES']='2, 3'
net = Net().to(device)
# Out:
# GPU

# %%
#optimizer
optimizer = optim.Adam(net.parameters(), lr = 0.001) #learning rate
err_f = nn.MSELoss()

train_2d_X = torch.Tensor(X_2d_train).view(-1, 40, 40)
train_1d_X = torch.Tensor(X_1d_train)
train_y = torch.Tensor(y_train)

# %%
# Get the first image from your training data
#first_image = train_X[0]
#print(first_image.shape) #TODO: can remove this line, added for testing

# Get the height and width of the first image
height, width = train_2d_X.shape[1], train_2d_X.shape[2]

#training
BATCH_SIZE = 16
EPOH = 10
N = 5 #how ofter we print loss
EPSILON = 0.0001 #if loss different under this

running_loss = 0.0
all_losses = [100]
for epoch in range(EPOH):
    for i in range(0, len(train_2d_X), BATCH_SIZE):
        batch_X_2d = train_2d_X[i:i+BATCH_SIZE].view(-1,1,height,width).to(device)
        batch_X_1d = train_1d_X[i:i+BATCH_SIZE].to(device)
        batch_y = train_y[i:i+BATCH_SIZE].to(device)

        #batch_X_2d, batch_X_1d, batch_y = batch_X_2d.to(device), batch_X_1d.to(device), batch_y.to(device)

        net.zero_grad() #zero gradient
        out = net(batch_X_2d, batch_X_1d)
        err = err_f(out, batch_y)
        err.backward()
        optimizer.step()
        
        running_loss += err.item()
    # Generate a permutation of indices
    perm = torch.randperm(train_2d_X.size(0))
    # Use the permutation to shuffle the tensors
    train_2d_X = train_2d_X[perm]
    train_1d_X = train_1d_X[perm]
    train_y = train_y[perm]

    if epoch % N == N-1:
        print("EPOH {}/{} loss: {}".format(epoch+1, EPOH, running_loss/N))
        all_losses.insert(0, running_loss/N)
        if all_losses[1]-all_losses[0] < EPSILON: #less than percent impromvenet
            break
        running_loss = 0.0
    if epoch % 5*N == 5*N-1:
        clear_output(wait=True)
# Out:
# EPOH 5/10 loss: 1.6668753600955823
# EPOH 10/10 loss: 0.3297709990716612

# %%
# Save the reduced model
torch.save(net.state_dict(), 'model_new.pth')

# %%
# Save the whole model
torch.save(net.state_dict(), 'model.pth')

# %% [markdown]
# ###   Run the mode over training set

# %%
net = Net().to(device)
net.load_state_dict(torch.load('model.pth'))
net.eval()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[263], line 2
#       1 net = Net().to(device)
# ----> 2 net.load_state_dict(torch.load('model.pth'))
#       3 net.eval()
#
# File d:\Anaconda\envs\IASR\Lib\site-packages\torch\nn\modules\module.py:2152, in Module.load_state_dict(self, state_dict, strict, assign)
#    2147         error_msgs.insert(
#    2148             0, 'Missing key(s) in state_dict: {}. '.format(
#    2149                 ', '.join(f'"{k}"' for k in missing_keys)))
#    2151 if len(error_msgs) > 0:
# -> 2152     raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    2153                        self.__class__.__name__, "\n\t".join(error_msgs)))
#    2154 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for Net:
# 	Unexpected key(s) in state_dict: "conv3.weight", "conv3.bias".
# 	size mismatch for conv1.weight: copying a param with shape torch.Size([8, 1, 7, 7]) from checkpoint, the shape in current model is torch.Size([20, 1, 5, 5]).
# 	size mismatch for conv1.bias: copying a param with shape torch.Size([8]) from checkpoint, the shape in current model is torch.Size([20]).
# 	size mismatch for conv2.weight: copying a param with shape torch.Size([16, 8, 5, 5]) from checkpoint, the shape in current model is torch.Size([30, 20, 3, 3]).
# 	size mismatch for conv2.bias: copying a param with shape torch.Size([16]) from checkpoint, the shape in current model is torch.Size([30]).
# 	size mismatch for conv3_bn.weight: copying a param with shape torch.Size([32]) from checkpoint, the shape in current model is torch.Size([30]).
# 	size mismatch for conv3_bn.bias: copying a param with shape torch.Size([32]) from checkpoint, the shape in current model is torch.Size([30]).
# 	size mismatch for conv3_bn.running_mean: copying a param with shape torch.Size([32]) from checkpoint, the shape in current model is torch.Size([30]).
# 	size mismatch for conv3_bn.running_var: copying a param with shape torch.Size([32]) from checkpoint, the shape in current model is torch.Size([30]).
# 	size mismatch for fc1.weight: copying a param with shape torch.Size([256, 143]) from checkpoint, the shape in current model is torch.Size([256, 1935]).

# %%
missclassified = 0
actual = []
predicted = []
net.eval()
with torch.no_grad():
    data_2d = torch.Tensor(X_2d_train).view(-1,1,height,width).to(device) #flatten
    data_1d = torch.Tensor(X_1d_train).to(device)
    #data_2d = data_2d.view(-1,1,height,width)
    output = net(data_2d, data_1d).to(device).cpu()

    for i in range(output.shape[0]):
        classification = torch.argmax(output[i])
        base_truth = np.argmax(y_train[i])
        predicted.append(classification)
        actual.append(base_truth)
        print("{} ; {}".format(labels[base_truth], labels[classification]))
        if base_truth != classification:
            missclassified += 1

print(missclassified / y_train.shape[0])
confusion_matrix = metrics.confusion_matrix(actual, predicted)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = labels)
cm_display.plot()
plt.show()
# Out:
# six ; six
# over ; over
# seven ; seven
# seven ; seven
# nine ; nine
# three ; three
# times ; times
# seven ; seven
# seven ; seven
# seven ; seven
# nine ; nine
# plus ; plus
# plus ; plus
# three ; three
# over ; over
# three ; three
# times ; times
# zero ; zero
# one ; one
# zero ; zero
# seven ; seven
# seven ; seven
# plus ; plus
# seven ; seven
# eight ; eight
# nine ; nine
# plus ; plus
# plus ; plus
# two ; two
# seven ; seven
# eight ; eight
# four ; four
# nine ; nine
# four ; four
# over ; over
# two ; two
# minus ; minus
# one ; one
# seven ; seven
# seven ; seven
# times ; times
# one ; one
# five ; five
# zero ; zero
# minus ; minus
# six ; six
# three ; three
# five ; five
# seven ; seven
# two ; two
# over ; over
# times ; times
# zero ; zero
# eight ; eight
# zero ; zero
# five ; five
# one ; one
# six ; six
# four ; four
# zero ; zero
# minus ; minus
# two ; two
# seven ; seven
# over ; over
# five ; five
# zero ; zero
# over ; over
# six ; six
# eight ; eight
# four ; four
# three ; three
# plus ; plus
# minus ; minus
# times ; times
# nine ; nine
# times ; times
# two ; two
# one ; one
# plus ; plus
# four ; four
# two ; two
# five ; five
# one ; one
# seven ; seven
# nine ; nine
# zero ; zero
# five ; five
# eight ; eight
# six ; six
# times ; times
# zero ; zero
# eight ; eight
# seven ; seven
# plus ; plus
# six ; six
# two ; two
# plus ; plus
# one ; one
# five ; five
# six ; six
# two ; two
# nine ; nine
# two ; two
# one ; one
# times ; times
# eight ; eight
# plus ; plus
# eight ; eight
# one ; one
# three ; three
# nine ; nine
# three ; three
# minus ; minus
# minus ; minus
# over ; over
# five ; five
# four ; four
# two ; two
# seven ; seven
# five ; five
# four ; four
# five ; five
# over ; over
# zero ; zero
# over ; over
# four ; four
# nine ; nine
# minus ; minus
# times ; times
# zero ; zero
# zero ; two
# minus ; minus
# six ; six
# seven ; seven
# eight ; eight
# one ; one
# three ; three
# zero ; zero
# minus ; minus
# over ; over
# minus ; minus
# five ; five
# three ; three
# eight ; eight
# minus ; minus
# six ; six
# five ; five
# times ; times
# five ; five
# one ; one
# over ; over
# three ; three
# six ; six
# three ; three
# one ; one
# nine ; nine
# one ; one
# five ; five
# minus ; minus
# nine ; nine
# plus ; plus
# eight ; eight
# two ; two
# times ; times
# seven ; seven
# one ; one
# five ; five
# six ; six
# nine ; nine
# one ; one
# six ; six
# one ; one
# zero ; zero
# one ; one
# seven ; seven
# four ; four
# eight ; eight
# plus ; plus
# plus ; plus
# eight ; eight
# seven ; seven
# eight ; eight
# zero ; zero
# nine ; nine
# two ; two
# three ; three
# six ; six
# seven ; seven
# over ; over
# times ; times
# nine ; nine
# five ; five
# over ; over
# over ; over
# nine ; nine
# zero ; zero
# one ; one
# nine ; nine
# times ; times
# four ; four
# minus ; minus
# eight ; eight
# plus ; plus
# times ; times
# four ; four
# eight ; eight
# plus ; plus
# over ; over
# eight ; eight
# seven ; seven
# times ; times
# nine ; nine
# six ; six
# nine ; nine
# one ; one
# zero ; zero
# times ; times
# seven ; seven
# four ; four
# seven ; seven
# six ; six
# four ; four
# five ; five
# six ; six
# two ; two
# six ; six
# five ; five
# five ; five
# five ; five
# five ; five
# eight ; eight
# four ; four
# six ; six
# seven ; seven
# times ; times
# seven ; seven
# times ; times
# over ; over
# eight ; eight
# seven ; seven
# eight ; eight
# three ; over
# nine ; nine
# plus ; plus
# five ; five
# seven ; seven
# five ; five
# over ; over
# eight ; eight
# times ; times
# seven ; seven
# one ; one
# nine ; nine
# six ; six
# over ; over
# nine ; nine
# four ; four
# six ; six
# two ; two
# four ; four
# nine ; nine
# plus ; plus
# three ; three
# plus ; plus
# over ; over
# two ; two
# minus ; minus
# one ; one
# one ; one
# five ; five
# seven ; seven
# zero ; zero
# eight ; eight
# three ; three
# one ; one
# five ; five
# eight ; eight
# four ; four
# over ; over
# one ; one
# nine ; nine
# nine ; nine
# nine ; nine
# nine ; nine
# plus ; plus
# seven ; seven
# three ; three
# four ; four
# nine ; nine
# times ; times
# zero ; zero
# one ; one
# nine ; nine
# three ; three
# six ; six
# five ; five
# zero ; zero
# minus ; minus
# eight ; eight
# three ; three
# five ; five
# over ; over
# eight ; eight
# one ; one
# one ; one
# one ; one
# three ; three
# nine ; nine
# zero ; zero
# nine ; nine
# zero ; zero
# one ; one
# times ; times
# nine ; nine
# minus ; minus
# zero ; zero
# minus ; minus
# seven ; seven
# eight ; eight
# four ; four
# six ; six
# times ; times
# four ; four
# three ; three
# four ; four
# zero ; zero
# five ; five
# four ; four
# times ; times
# seven ; seven
# four ; four
# minus ; minus
# minus ; minus
# times ; times
# eight ; eight
# four ; four
# three ; three
# four ; four
# two ; two
# minus ; minus
# one ; one
# six ; six
# one ; one
# three ; three
# one ; one
# one ; one
# zero ; zero
# six ; six
# three ; three
# zero ; zero
# times ; times
# minus ; minus
# five ; five
# five ; five
# two ; two
# seven ; seven
# eight ; eight
# plus ; plus
# four ; four
# seven ; seven
# over ; over
# seven ; seven
# minus ; minus
# plus ; plus
# two ; two
# one ; one
# eight ; eight
# one ; one
# zero ; zero
# seven ; seven
# six ; six
# eight ; eight
# eight ; eight
# over ; over
# three ; three
# nine ; nine
# over ; over
# eight ; eight
# nine ; nine
# seven ; seven
# zero ; zero
# over ; over
# minus ; minus
# times ; times
# eight ; eight
# three ; three
# minus ; minus
# plus ; plus
# minus ; minus
# over ; over
# nine ; nine
# six ; six
# over ; over
# seven ; seven
# one ; one
# four ; four
# seven ; seven
# nine ; nine
# seven ; seven
# seven ; seven
# four ; four
# six ; six
# one ; one
# over ; over
# times ; times
# five ; five
# plus ; plus
# five ; five
# minus ; minus
# eight ; eight
# nine ; nine
# two ; two
# six ; six
# one ; one
# plus ; plus
# nine ; nine
# nine ; nine
# four ; four
# zero ; zero
# six ; six
# four ; four
# six ; six
# eight ; eight
# nine ; nine
# two ; two
# minus ; minus
# times ; times
# two ; two
# over ; over
# one ; one
# eight ; eight
# minus ; minus
# times ; times
# six ; six
# eight ; eight
# eight ; eight
# plus ; plus
# five ; five
# zero ; zero
# minus ; minus
# eight ; eight
# over ; over
# four ; four
# five ; five
# three ; three
# two ; two
# four ; four
# three ; three
# two ; two
# two ; two
# zero ; zero
# minus ; minus
# times ; times
# nine ; nine
# five ; five
# four ; four
# over ; over
# plus ; plus
# minus ; minus
# nine ; nine
# five ; five
# eight ; eight
# four ; four
# five ; five
# four ; four
# seven ; seven
# minus ; minus
# plus ; plus
# four ; four
# eight ; eight
# over ; over
# plus ; plus
# three ; three
# over ; over
# five ; five
# five ; five
# three ; three
# three ; three
# over ; over
# minus ; minus
# three ; three
# six ; six
# seven ; seven
# times ; times
# six ; six
# plus ; plus
# six ; six
# six ; six
# seven ; seven
# zero ; zero
# eight ; eight
# times ; times
# seven ; seven
# four ; four
# zero ; zero
# nine ; nine
# times ; times
# six ; six
# zero ; zero
# seven ; seven
# minus ; minus
# nine ; nine
# eight ; eight
# four ; four
# nine ; nine
# minus ; minus
# plus ; plus
# five ; five
# three ; three
# eight ; eight
# three ; three
# two ; two
# nine ; nine
# one ; one
# six ; six
# eight ; eight
# six ; six
# five ; five
# three ; three
# zero ; zero
# five ; five
# three ; three
# seven ; seven
# over ; over
# three ; three
# four ; four
# one ; one
# times ; times
# two ; two
# plus ; plus
# five ; five
# over ; over
# seven ; seven
# four ; four
# zero ; zero
# minus ; minus
# six ; six
# over ; over
# five ; five
# six ; six
# six ; six
# plus ; plus
# six ; six
# six ; six
# eight ; eight
# seven ; seven
# one ; one
# seven ; seven
# two ; two
# four ; four
# nine ; nine
# five ; five
# minus ; minus
# four ; four
# five ; five
# six ; six
# zero ; zero
# three ; three
# plus ; plus
# four ; four
# five ; five
# seven ; seven
# four ; four
# two ; two
# one ; two
# plus ; plus
# two ; two
# one ; one
# times ; times
# nine ; nine
# nine ; nine
# seven ; seven
# nine ; nine
# four ; four
# five ; five
# eight ; eight
# five ; five
# times ; times
# four ; four
# times ; times
# six ; six
# seven ; seven
# minus ; minus
# over ; over
# over ; over
# eight ; eight
# over ; over
# seven ; seven
# seven ; seven
# six ; six
# nine ; nine
# over ; over
# three ; three
# over ; over
# seven ; seven
# three ; three
# eight ; eight
# times ; times
# four ; four
# four ; four
# times ; times
# nine ; nine
# four ; four
# nine ; nine
# three ; three
# zero ; zero
# five ; five
# five ; five
# over ; over
# six ; six
# nine ; nine
# four ; four
# three ; three
# six ; six
# over ; over
# two ; two
# four ; four
# seven ; seven
# over ; over
# seven ; seven
# four ; four
# one ; one
# five ; five
# plus ; plus
# one ; one
# six ; six
# zero ; zero
# zero ; zero
# plus ; plus
# zero ; zero
# eight ; eight
# four ; four
# minus ; minus
# three ; three
# seven ; seven
# four ; four
# zero ; zero
# nine ; nine
# four ; four
# zero ; zero
# four ; four
# eight ; eight
# nine ; nine
# minus ; minus
# five ; five
# over ; over
# four ; four
# minus ; minus
# five ; five
# over ; over
# five ; five
# three ; three
# one ; one
# eight ; eight
# one ; one
# nine ; nine
# zero ; zero
# zero ; zero
# four ; four
# five ; five
# five ; five
# seven ; seven
# three ; three
# six ; six
# eight ; eight
# minus ; minus
# two ; two
# five ; five
# four ; four
# five ; five
# five ; five
# one ; one
# plus ; plus
# eight ; eight
# zero ; zero
# four ; four
# over ; over
# two ; two
# seven ; seven
# minus ; minus
# eight ; eight
# three ; three
# over ; over
# four ; four
# over ; over
# five ; five
# six ; six
# seven ; seven
# seven ; seven
# one ; one
# five ; five
# nine ; nine
# four ; four
# four ; four
# one ; one
# four ; four
# five ; five
# three ; three
# seven ; seven
# minus ; minus
# five ; five
# three ; three
# over ; over
# plus ; plus
# three ; three
# eight ; eight
# nine ; nine
# seven ; seven
# one ; one
# times ; times
# seven ; seven
# nine ; nine
# eight ; eight
# six ; six
# two ; two
# minus ; minus
# three ; three
# zero ; zero
# eight ; eight
# eight ; eight
# eight ; eight
# five ; five
# minus ; minus
# one ; one
# five ; five
# plus ; plus
# minus ; minus
# seven ; seven
# four ; four
# four ; four
# times ; times
# over ; over
# four ; four
# seven ; seven
# two ; two
# five ; five
# seven ; seven
# five ; five
# five ; five
# seven ; seven
# two ; two
# seven ; seven
# zero ; zero
# two ; two
# nine ; nine
# zero ; zero
# seven ; seven
# five ; five
# eight ; eight
# nine ; nine
# one ; one
# three ; three
# minus ; minus
# two ; two
# minus ; minus
# plus ; plus
# minus ; minus
# zero ; zero
# four ; four
# six ; six
# one ; one
# over ; over
# eight ; eight
# one ; one
# seven ; seven
# plus ; plus
# seven ; seven
# six ; six
# plus ; plus
# minus ; minus
# times ; times
# plus ; plus
# five ; five
# over ; over
# plus ; plus
# five ; five
# plus ; plus
# nine ; nine
# eight ; eight
# three ; three
# five ; five
# two ; two
# seven ; seven
# six ; six
# one ; one
# two ; two
# nine ; nine
# one ; one
# over ; over
# five ; five
# three ; three
# one ; one
# seven ; seven
# zero ; zero
# four ; four
# eight ; eight
# three ; three
# eight ; eight
# nine ; nine
# four ; four
# five ; five
# five ; five
# minus ; minus
# four ; four
# zero ; zero
# one ; one
# over ; over
# three ; three
# seven ; seven
# four ; four
# three ; three
# four ; four
# three ; three
# minus ; minus
# four ; four
# seven ; seven
# eight ; eight
# nine ; nine
# seven ; seven
# five ; five
# over ; over
# nine ; nine
# plus ; plus
# seven ; seven
# times ; times
# three ; three
# three ; three
# nine ; nine
# seven ; seven
# times ; times
# four ; four
# plus ; plus
# minus ; minus
# over ; over
# four ; four
# three ; three
# eight ; eight
# three ; three
# nine ; nine
# four ; four
# times ; times
# two ; two
# times ; times
# two ; two
# four ; four
# four ; four
# nine ; nine
# times ; times
# minus ; minus
# five ; five
# minus ; minus
# times ; times
# eight ; eight
# eight ; eight
# six ; six
# six ; six
# six ; six
# times ; times
# five ; five
# four ; four
# plus ; plus
# one ; one
# one ; one
# four ; four
# one ; one
# times ; times
# seven ; seven
# one ; one
# one ; one
# zero ; zero
# eight ; eight
# plus ; plus
# four ; four
# four ; four
# eight ; eight
# four ; four
# times ; times
# six ; six
# zero ; zero
# eight ; eight
# nine ; nine
# zero ; zero
# two ; two
# over ; over
# zero ; zero
# three ; three
# minus ; minus
# five ; five
# minus ; minus
# nine ; nine
# nine ; nine
# seven ; seven
# three ; three
# one ; one
# five ; five
# five ; five
# nine ; nine
# four ; four
# five ; five
# plus ; plus
# seven ; seven
# seven ; seven
# nine ; nine
# nine ; nine
# times ; times
# seven ; seven
# seven ; seven
# nine ; nine
# three ; three
# eight ; eight
# four ; four
# times ; times
# four ; four
# over ; over
# seven ; seven
# four ; four
# six ; six
# eight ; eight
# seven ; seven
# eight ; eight
# four ; four
# over ; over
# one ; one
# two ; two
# minus ; minus
# two ; two
# eight ; eight
# seven ; seven
# nine ; nine
# plus ; plus
# one ; one
# over ; over
# three ; three
# zero ; zero
# four ; four
# times ; times
# five ; five
# seven ; seven
# plus ; plus
# seven ; seven
# one ; one
# minus ; minus
# zero ; zero
# one ; one
# seven ; seven
# four ; four
# five ; five
# two ; two
# two ; two
# seven ; seven
# minus ; minus
# five ; five
# five ; five
# zero ; zero
# one ; one
# one ; one
# zero ; zero
# three ; three
# nine ; nine
# zero ; zero
# zero ; zero
# eight ; eight
# four ; four
# three ; three
# five ; five
# zero ; zero
# four ; four
# four ; four
# minus ; minus
# plus ; plus
# one ; one
# zero ; zero
# four ; four
# eight ; eight
# nine ; nine
# zero ; zero
# over ; over
# two ; two
# minus ; minus
# plus ; plus
# six ; six
# times ; times
# nine ; nine
# eight ; eight
# eight ; eight
# zero ; zero
# six ; six
# three ; three
# one ; one
# one ; one
# seven ; seven
# eight ; eight
# one ; one
# two ; two
# seven ; seven
# minus ; minus
# nine ; nine
# nine ; nine
# three ; three
# six ; six
# five ; five
# over ; over
# one ; one
# over ; over
# five ; five
# four ; four
# plus ; plus
# times ; times
# six ; six
# one ; one
# seven ; seven
# plus ; plus
# four ; four
# seven ; seven
# two ; two
# nine ; nine
# six ; six
# four ; four
# nine ; nine
# seven ; seven
# six ; six
# minus ; minus
# plus ; plus
# eight ; eight
# nine ; nine
# four ; four
# eight ; eight
# five ; five
# zero ; zero
# over ; over
# zero ; zero
# nine ; nine
# five ; five
# plus ; plus
# minus ; minus
# six ; six
# eight ; eight
# two ; two
# one ; one
# two ; two
# minus ; minus
# two ; two
# five ; five
# three ; three
# zero ; zero
# over ; over
# six ; six
# times ; times
# eight ; eight
# plus ; plus
# minus ; minus
# minus ; minus
# eight ; eight
# five ; five
# plus ; plus
# five ; five
# four ; four
# six ; six
# minus ; minus
# nine ; nine
# five ; five
# six ; six
# eight ; eight
# seven ; seven
# five ; five
# four ; four
# five ; five
# zero ; zero
# three ; three
# plus ; plus
# eight ; eight
# six ; six
# zero ; zero
# times ; times
# one ; one
# minus ; minus
# plus ; plus
# four ; four
# five ; five
# zero ; zero
# seven ; seven
# eight ; eight
# seven ; seven
# six ; six
# seven ; seven
# minus ; minus
# zero ; zero
# over ; over
# six ; six
# times ; times
# nine ; nine
# seven ; seven
# eight ; eight
# zero ; zero
# four ; four
# two ; two
# minus ; minus
# nine ; nine
# nine ; nine
# seven ; seven
# eight ; eight
# minus ; minus
# six ; six
# over ; over
# nine ; nine
# times ; times
# one ; one
# six ; six
# zero ; zero
# over ; over
# three ; three
# seven ; seven
# four ; four
# five ; five
# times ; times
# seven ; seven
# nine ; nine
# times ; times
# five ; five
# six ; six
# one ; one
# zero ; zero
# five ; five
# minus ; minus
# one ; one
# three ; three
# four ; four
# six ; six
# minus ; minus
# plus ; plus
# plus ; plus
# one ; one
# minus ; minus
# five ; five
# four ; four
# zero ; zero
# four ; four
# five ; five
# six ; six
# five ; five
# zero ; zero
# zero ; zero
# one ; one
# six ; six
# nine ; nine
# three ; three
# two ; two
# over ; over
# three ; three
# plus ; plus
# minus ; minus
# one ; one
# plus ; plus
# plus ; plus
# seven ; seven
# eight ; eight
# zero ; zero
# nine ; nine
# plus ; plus
# plus ; plus
# seven ; seven
# seven ; seven
# six ; six
# zero ; zero
# over ; over
# six ; six
# plus ; plus
# times ; times
# one ; one
# nine ; nine
# plus ; plus
# three ; three
# zero ; zero
# six ; six
# six ; six
# six ; six
# times ; times
# two ; two
# three ; three
# seven ; seven
# nine ; nine
# zero ; zero
# zero ; zero
# three ; three
# four ; four
# six ; six
# eight ; eight
# zero ; zero
# seven ; seven
# four ; four
# nine ; nine
# four ; four
# zero ; zero
# over ; over
# zero ; zero
# one ; one
# zero ; zero
# nine ; nine
# three ; three
# seven ; seven
# zero ; zero
# five ; five
# six ; six
# eight ; eight
# plus ; plus
# times ; times
# zero ; zero
# zero ; zero
# over ; over
# zero ; zero
# eight ; eight
# times ; times
# eight ; eight
# times ; times
# two ; two
# over ; over
# plus ; plus
# five ; five
# over ; over
# five ; five
# seven ; seven
# nine ; nine
# four ; four
# eight ; eight
# three ; three
# minus ; minus
# five ; five
# times ; times
# over ; over
# two ; two
# nine ; nine
# times ; times
# eight ; eight
# six ; six
# eight ; eight
# zero ; zero
# minus ; minus
# four ; four
# eight ; eight
# plus ; plus
# plus ; plus
# four ; four
# zero ; zero
# minus ; minus
# four ; four
# seven ; seven
# times ; times
# one ; one
# zero ; zero
# one ; one
# five ; five
# one ; one
# four ; four
# zero ; zero
# over ; over
# one ; one
# plus ; plus
# three ; three
# six ; six
# two ; two
# times ; times
# seven ; seven
# over ; over
# three ; three
# nine ; nine
# five ; five
# six ; six
# six ; six
# plus ; plus
# four ; four
# three ; three
# one ; one
# zero ; zero
# plus ; plus
# zero ; zero
# minus ; minus
# eight ; eight
# zero ; zero
# three ; three
# four ; four
# five ; five
# five ; five
# six ; six
# zero ; zero
# six ; six
# five ; five
# zero ; zero
# five ; five
# two ; two
# six ; six
# zero ; zero
# eight ; eight
# eight ; eight
# five ; five
# plus ; plus
# plus ; plus
# zero ; zero
# zero ; zero
# eight ; eight
# over ; over
# plus ; plus
# minus ; minus
# four ; four
# two ; two
# times ; times
# nine ; nine
# minus ; minus
# nine ; nine
# over ; over
# zero ; zero
# six ; six
# two ; two
# nine ; nine
# five ; five
# four ; four
# plus ; plus
# three ; three
# one ; one
# five ; five
# six ; six
# three ; three
# three ; three
# over ; over
# nine ; nine
# three ; three
# eight ; eight
# six ; six
# four ; four
# nine ; nine
# times ; times
# three ; three
# eight ; eight
# plus ; plus
# five ; five
# nine ; nine
# five ; five
# plus ; plus
# times ; times
# zero ; zero
# minus ; minus
# eight ; eight
# one ; one
# over ; over
# seven ; seven
# eight ; eight
# four ; four
# eight ; eight
# five ; five
# one ; one
# plus ; plus
# eight ; eight
# over ; over
# seven ; seven
# times ; times
# one ; one
# eight ; eight
# three ; three
# four ; four
# eight ; eight
# plus ; plus
# four ; four
# over ; over
# three ; three
# times ; times
# times ; times
# three ; three
# seven ; seven
# plus ; plus
# five ; five
# zero ; zero
# four ; four
# over ; over
# plus ; plus
# six ; six
# seven ; seven
# nine ; nine
# over ; over
# four ; four
# four ; four
# nine ; nine
# plus ; plus
# seven ; seven
# one ; one
# five ; five
# nine ; nine
# plus ; plus
# times ; times
# nine ; nine
# six ; six
# six ; six
# five ; five
# four ; four
# eight ; eight
# times ; times
# six ; six
# six ; six
# six ; six
# times ; times
# three ; three
# zero ; zero
# nine ; nine
# two ; two
# five ; five
# two ; two
# one ; one
# three ; three
# two ; two
# three ; three
# two ; two
# six ; six
# five ; five
# one ; one
# five ; five
# three ; three
# zero ; zero
# zero ; zero
# over ; over
# times ; times
# times ; times
# nine ; nine
# plus ; plus
# one ; one
# one ; one
# eight ; eight
# nine ; nine
# over ; over
# six ; six
# nine ; nine
# four ; four
# five ; five
# minus ; minus
# zero ; zero
# zero ; zero
# times ; times
# five ; five
# times ; times
# one ; one
# six ; six
# five ; five
# zero ; zero
# eight ; eight
# six ; six
# five ; five
# times ; times
# five ; five
# times ; times
# nine ; nine
# nine ; nine
# five ; five
# zero ; zero
# eight ; eight
# six ; six
# eight ; eight
# four ; four
# seven ; seven
# seven ; seven
# zero ; zero
# four ; four
# zero ; zero
# five ; five
# three ; three
# three ; three
# over ; over
# seven ; seven
# plus ; plus
# eight ; eight
# five ; five
# five ; five
# nine ; nine
# two ; two
# zero ; zero
# eight ; eight
# minus ; minus
# three ; three
# over ; over
# one ; one
# three ; three
# nine ; nine
# four ; four
# one ; one
# four ; four
# over ; over
# nine ; nine
# five ; five
# plus ; plus
# eight ; eight
# three ; three
# plus ; plus
# minus ; minus
# eight ; eight
# two ; two
# plus ; plus
# two ; two
# two ; two
# eight ; eight
# times ; times
# over ; over
# seven ; seven
# four ; four
# over ; over
# minus ; minus
# seven ; seven
# two ; two
# times ; times
# zero ; zero
# seven ; seven
# four ; four
# minus ; minus
# six ; six
# eight ; eight
# nine ; nine
# seven ; seven
# nine ; nine
# five ; five
# five ; five
# one ; one
# nine ; nine
# two ; two
# over ; over
# five ; five
# over ; over
# times ; times
# four ; four
# four ; four
# nine ; nine
# seven ; seven
# eight ; eight
# times ; times
# over ; over
# six ; six
# nine ; nine
# four ; four
# plus ; plus
# eight ; eight
# one ; one
# six ; six
# one ; one
# zero ; zero
# seven ; seven
# four ; four
# times ; times
# six ; six
# five ; five
# minus ; minus
# over ; over
# zero ; zero
# one ; one
# zero ; zero
# five ; five
# times ; times
# zero ; zero
# minus ; minus
# one ; one
# five ; five
# seven ; seven
# three ; three
# zero ; zero
# zero ; zero
# zero ; zero
# one ; one
# five ; five
# six ; six
# one ; one
# two ; two
# minus ; minus
# zero ; zero
# zero ; zero
# zero ; zero
# two ; two
# eight ; eight
# four ; four
# zero ; zero
# seven ; seven
# four ; four
# three ; three
# over ; over
# nine ; nine
# plus ; plus
# plus ; plus
# nine ; nine
# four ; four
# one ; one
# four ; four
# three ; three
# eight ; eight
# eight ; eight
# one ; one
# seven ; seven
# seven ; seven
# two ; two
# zero ; zero
# nine ; nine
# minus ; minus
# five ; five
# times ; times
# five ; five
# three ; three
# zero ; zero
# zero ; zero
# over ; over
# five ; five
# over ; over
# times ; times
# three ; three
# nine ; nine
# five ; five
# over ; over
# six ; six
# nine ; nine
# zero ; zero
# one ; one
# one ; one
# over ; over
# seven ; seven
# plus ; plus
# eight ; eight
# four ; four
# times ; times
# six ; six
# one ; one
# nine ; nine
# zero ; zero
# six ; six
# seven ; seven
# one ; one
# three ; three
# times ; times
# seven ; seven
# nine ; nine
# two ; two
# five ; five
# one ; one
# five ; five
# zero ; zero
# eight ; eight
# eight ; eight
# three ; three
# eight ; eight
# four ; four
# nine ; nine
# four ; four
# over ; over
# minus ; minus
# two ; two
# three ; three
# one ; one
# five ; five
# one ; one
# seven ; seven
# over ; over
# nine ; nine
# five ; five
# seven ; seven
# eight ; eight
# minus ; minus
# zero ; zero
# four ; four
# three ; three
# four ; four
# five ; five
# minus ; minus
# eight ; eight
# three ; three
# minus ; minus
# plus ; plus
# one ; one
# seven ; seven
# five ; five
# times ; times
# times ; times
# one ; one
# one ; one
# six ; six
# minus ; minus
# over ; over
# nine ; nine
# two ; two
# nine ; nine
# three ; three
# four ; four
# zero ; zero
# one ; one
# seven ; seven
# six ; six
# over ; over
# times ; times
# nine ; nine
# plus ; plus
# times ; times
# one ; one
# three ; three
# zero ; zero
# nine ; nine
# plus ; plus
# seven ; seven
# eight ; eight
# six ; six
# five ; five
# six ; six
# three ; three
# zero ; zero
# seven ; seven
# five ; five
# minus ; minus
# nine ; nine
# nine ; nine
# plus ; plus
# minus ; minus
# nine ; nine
# seven ; seven
# one ; one
# eight ; eight
# two ; two
# five ; five
# four ; four
# three ; three
# seven ; seven
# one ; one
# plus ; plus
# zero ; zero
# zero ; zero
# six ; six
# nine ; nine
# five ; five
# nine ; nine
# nine ; nine
# seven ; seven
# seven ; seven
# four ; four
# six ; six
# two ; two
# five ; five
# minus ; minus
# one ; one
# one ; one
# seven ; seven
# six ; six
# one ; one
# three ; three
# minus ; minus
# one ; one
# two ; two
# two ; two
# four ; four
# three ; three
# plus ; plus
# plus ; plus
# seven ; seven
# six ; six
# four ; four
# seven ; seven
# seven ; seven
# six ; six
# over ; over
# four ; four
# zero ; zero
# five ; five
# eight ; eight
# three ; three
# nine ; nine
# five ; five
# one ; one
# seven ; seven
# eight ; eight
# over ; over
# five ; five
# eight ; eight
# over ; over
# plus ; plus
# nine ; nine
# plus ; plus
# two ; two
# seven ; seven
# seven ; seven
# zero ; zero
# seven ; seven
# four ; four
# six ; six
# plus ; plus
# zero ; zero
# eight ; eight
# four ; four
# five ; five
# over ; over
# times ; times
# nine ; nine
# seven ; seven
# five ; five
# times ; times
# eight ; eight
# seven ; seven
# zero ; zero
# eight ; eight
# plus ; plus
# six ; six
# plus ; plus
# eight ; eight
# minus ; minus
# over ; over
# five ; five
# one ; one
# two ; two
# seven ; seven
# seven ; seven
# eight ; eight
# four ; four
# one ; one
# one ; one
# six ; six
# four ; four
# minus ; minus
# six ; six
# eight ; five
# one ; one
# minus ; minus
# zero ; zero
# two ; two
# plus ; plus
# nine ; nine
# four ; four
# eight ; eight
# one ; one
# times ; times
# minus ; minus
# three ; three
# three ; three
# nine ; nine
# seven ; seven
# six ; six
# minus ; minus
# two ; two
# seven ; seven
# times ; times
# one ; one
# minus ; minus
# zero ; zero
# one ; one
# zero ; zero
# one ; one
# minus ; plus
# four ; four
# seven ; seven
# six ; six
# three ; three
# zero ; zero
# times ; times
# seven ; seven
# over ; over
# one ; one
# four ; four
# two ; six
# seven ; seven
# nine ; nine
# six ; six
# zero ; zero
# nine ; nine
# five ; five
# four ; four
# eight ; eight
# seven ; seven
# over ; over
# plus ; plus
# five ; five
# plus ; plus
# zero ; zero
# six ; six
# one ; one
# minus ; minus
# zero ; zero
# four ; four
# seven ; two
# seven ; seven
# four ; four
# five ; five
# times ; times
# one ; one
# four ; four
# eight ; eight
# nine ; nine
# plus ; plus
# three ; three
# plus ; plus
# over ; over
# one ; one
# one ; one
# four ; four
# one ; one
# four ; four
# nine ; nine
# minus ; minus
# one ; one
# over ; over
# zero ; zero
# eight ; eight
# one ; one
# nine ; nine
# over ; over
# four ; four
# zero ; zero
# nine ; nine
# zero ; zero
# six ; six
# five ; five
# minus ; minus
# zero ; zero
# eight ; eight
# five ; five
# minus ; minus
# zero ; zero
# one ; one
# three ; three
# seven ; seven
# five ; five
# nine ; nine
# two ; two
# seven ; seven
# seven ; seven
# over ; over
# two ; two
# seven ; seven
# five ; five
# zero ; zero
# plus ; plus
# times ; times
# one ; one
# zero ; zero
# five ; five
# nine ; nine
# five ; five
# eight ; eight
# one ; one
# one ; one
# times ; times
# six ; six
# one ; one
# times ; times
# zero ; zero
# times ; times
# times ; times
# seven ; seven
# six ; six
# five ; five
# five ; five
# five ; five
# minus ; minus
# zero ; zero
# minus ; minus
# five ; five
# six ; six
# nine ; nine
# nine ; nine
# one ; one
# eight ; eight
# times ; times
# three ; three
# one ; one
# three ; three
# six ; six
# over ; over
# minus ; minus
# eight ; eight
# times ; times
# nine ; nine
# five ; five
# times ; times
# nine ; nine
# plus ; plus
# four ; four
# four ; four
# minus ; minus
# eight ; eight
# over ; over
# eight ; eight
# four ; four
# plus ; plus
# minus ; minus
# two ; two
# six ; six
# zero ; zero
# one ; one
# minus ; minus
# nine ; nine
# four ; four
# plus ; plus
# five ; five
# three ; three
# five ; five
# eight ; eight
# nine ; nine
# one ; one
# two ; two
# over ; over
# two ; two
# over ; over
# zero ; zero
# over ; over
# one ; one
# minus ; minus
# one ; one
# zero ; zero
# six ; six
# four ; four
# zero ; zero
# seven ; seven
# nine ; nine
# four ; four
# over ; over
# three ; three
# nine ; nine
# two ; two
# seven ; seven
# eight ; eight
# eight ; eight
# five ; five
# zero ; zero
# seven ; seven
# five ; five
# two ; two
# eight ; eight
# four ; four
# minus ; minus
# eight ; eight
# one ; one
# two ; two
# three ; three
# nine ; nine
# nine ; nine
# three ; three
# plus ; plus
# one ; one
# four ; four
# times ; times
# four ; four
# zero ; zero
# eight ; eight
# times ; times
# one ; one
# three ; three
# times ; times
# plus ; plus
# zero ; zero
# plus ; plus
# one ; one
# zero ; zero
# nine ; nine
# plus ; plus
# one ; one
# one ; one
# eight ; eight
# eight ; eight
# zero ; zero
# four ; four
# four ; four
# nine ; nine
# nine ; nine
# eight ; eight
# seven ; seven
# six ; six
# times ; times
# six ; six
# seven ; seven
# zero ; zero
# nine ; nine
# six ; six
# seven ; seven
# zero ; zero
# zero ; zero
# eight ; eight
# zero ; zero
# nine ; nine
# one ; one
# nine ; nine
# times ; times
# seven ; seven
# plus ; plus
# times ; times
# four ; four
# five ; five
# one ; one
# eight ; eight
# six ; six
# times ; times
# over ; over
# three ; three
# six ; six
# eight ; eight
# zero ; zero
# four ; four
# five ; five
# four ; four
# zero ; zero
# three ; three
# minus ; minus
# five ; five
# one ; one
# five ; five
# four ; four
# five ; five
# four ; four
# four ; four
# three ; three
# nine ; nine
# eight ; eight
# two ; two
# zero ; zero
# eight ; eight
# nine ; nine
# eight ; eight
# four ; four
# two ; two
# nine ; nine
# plus ; plus
# minus ; minus
# three ; three
# plus ; plus
# two ; two
# seven ; seven
# plus ; plus
# two ; two
# over ; over
# over ; over
# nine ; nine
# seven ; seven
# five ; five
# minus ; minus
# seven ; seven
# zero ; zero
# five ; five
# plus ; plus
# eight ; eight
# six ; six
# four ; four
# zero ; zero
# six ; six
# six ; six
# two ; two
# three ; three
# five ; five
# five ; five
# three ; three
# one ; one
# six ; six
# two ; two
# minus ; minus
# eight ; eight
# eight ; eight
# plus ; plus
# zero ; zero
# zero ; zero
# nine ; nine
# zero ; zero
# four ; four
# six ; six
# zero ; zero
# seven ; seven
# zero ; zero
# eight ; eight
# minus ; minus
# minus ; minus
# times ; times
# over ; over
# zero ; zero
# three ; three
# five ; five
# over ; over
# eight ; eight
# one ; one
# four ; four
# five ; five
# zero ; zero
# seven ; seven
# zero ; zero
# eight ; eight
# eight ; eight
# minus ; minus
# seven ; seven
# nine ; nine
# over ; over
# four ; four
# nine ; nine
# times ; times
# eight ; eight
# zero ; zero
# three ; three
# zero ; zero
# five ; five
# five ; five
# over ; over
# four ; four
# minus ; minus
# seven ; seven
# seven ; seven
# nine ; nine
# eight ; eight
# five ; five
# plus ; plus
# three ; three
# zero ; zero
# four ; four
# three ; three
# plus ; plus
# two ; two
# seven ; seven
# eight ; eight
# nine ; nine
# plus ; plus
# four ; four
# times ; times
# three ; three
# four ; four
# five ; five
# minus ; minus
# eight ; eight
# times ; times
# times ; times
# zero ; zero
# one ; one
# four ; four
# five ; five
# two ; two
# five ; five
# four ; four
# six ; six
# seven ; seven
# four ; four
# over ; over
# zero ; zero
# one ; one
# over ; over
# zero ; zero
# over ; over
# one ; one
# four ; four
# nine ; nine
# nine ; nine
# three ; three
# three ; three
# five ; five
# five ; five
# one ; one
# five ; five
# one ; one
# nine ; nine
# five ; five
# minus ; minus
# plus ; plus
# eight ; eight
# times ; times
# three ; three
# one ; one
# times ; times
# four ; four
# one ; one
# three ; three
# four ; four
# six ; six
# six ; six
# times ; times
# seven ; seven
# over ; over
# one ; one
# six ; six
# nine ; nine
# two ; two
# zero ; zero
# seven ; seven
# nine ; nine
# seven ; seven
# three ; three
# one ; one
# eight ; eight
# four ; four
# nine ; nine
# three ; three
# two ; two
# four ; four
# six ; six
# three ; three
# six ; six
# five ; five
# zero ; zero
# four ; four
# zero ; zero
# zero ; zero
# nine ; nine
# eight ; eight
# zero ; zero
# seven ; seven
# six ; six
# two ; two
# 0.003056768558951965

# %%
missclassified = 0
actual = []
predicted = []
net.eval()
with torch.no_grad():
    data_2d = torch.Tensor(X_2d_test).view(-1,1,height,width).to(device) #flatten
    data_1d = torch.Tensor(X_1d_test).to(device)
    #data_2d = data_2d.view(-1,1,height,width)
    output = net(data_2d, data_1d).to(device).cpu()

    for i in range(output.shape[0]):
        classification = torch.argmax(output[i])
        base_truth = np.argmax(y_test[i])
        predicted.append(classification)
        actual.append(base_truth)
        print("{} ; {}".format(labels[base_truth], labels[classification]))
        if base_truth != classification:
            missclassified += 1

print(missclassified / y_test.shape[0])
confusion_matrix = metrics.confusion_matrix(actual, predicted)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = labels)
cm_display.plot()
plt.show()
# Out:
# nine ; nine
# three ; three
# four ; four
# over ; over
# four ; four
# two ; two
# four ; four
# four ; five
# one ; one
# eight ; eight
# zero ; zero
# seven ; seven
# seven ; seven
# six ; eight
# zero ; zero
# one ; one
# over ; over
# three ; three
# nine ; nine
# over ; over
# times ; times
# one ; one
# two ; two
# over ; over
# three ; three
# two ; two
# nine ; nine
# eight ; eight
# eight ; eight
# one ; nine
# plus ; plus
# eight ; eight
# one ; one
# one ; one
# one ; one
# plus ; plus
# times ; times
# plus ; plus
# eight ; eight
# three ; three
# three ; three
# nine ; nine
# minus ; minus
# two ; two
# one ; one
# eight ; eight
# three ; three
# minus ; minus
# minus ; minus
# eight ; eight
# six ; six
# two ; two
# six ; six
# one ; one
# times ; times
# times ; times
# five ; five
# over ; over
# minus ; times
# plus ; plus
# three ; three
# one ; one
# one ; one
# five ; five
# six ; six
# zero ; zero
# times ; times
# five ; five
# seven ; seven
# seven ; seven
# seven ; seven
# over ; over
# one ; one
# two ; two
# minus ; minus
# minus ; minus
# five ; nine
# over ; over
# six ; nine
# zero ; zero
# zero ; zero
# six ; six
# three ; three
# two ; two
# seven ; seven
# over ; over
# six ; six
# minus ; minus
# zero ; zero
# five ; five
# seven ; seven
# minus ; minus
# one ; one
# one ; one
# five ; five
# four ; four
# five ; five
# four ; four
# one ; one
# one ; one
# three ; three
# five ; five
# minus ; minus
# nine ; nine
# four ; four
# five ; five
# zero ; zero
# three ; three
# three ; three
# minus ; minus
# zero ; two
# plus ; plus
# seven ; seven
# nine ; nine
# four ; four
# seven ; seven
# nine ; nine
# over ; over
# seven ; seven
# six ; six
# seven ; seven
# eight ; eight
# three ; three
# four ; four
# three ; three
# zero ; zero
# over ; over
# three ; three
# over ; over
# minus ; nine
# four ; four
# minus ; two
# four ; four
# nine ; nine
# times ; times
# two ; two
# seven ; seven
# over ; over
# nine ; nine
# times ; times
# one ; one
# one ; one
# nine ; eight
# eight ; eight
# plus ; plus
# nine ; two
# two ; two
# seven ; seven
# one ; one
# six ; six
# one ; one
# over ; over
# four ; four
# nine ; nine
# seven ; seven
# five ; five
# zero ; zero
# eight ; eight
# times ; times
# five ; five
# four ; four
# times ; times
# plus ; six
# over ; over
# one ; one
# over ; over
# eight ; eight
# nine ; nine
# eight ; eight
# three ; eight
# seven ; seven
# seven ; seven
# nine ; nine
# seven ; seven
# zero ; zero
# nine ; nine
# times ; three
# over ; over
# times ; times
# one ; one
# eight ; eight
# six ; six
# eight ; eight
# three ; three
# seven ; seven
# seven ; seven
# four ; four
# one ; one
# nine ; nine
# five ; five
# five ; five
# plus ; plus
# nine ; nine
# zero ; zero
# minus ; minus
# zero ; zero
# seven ; seven
# four ; four
# three ; three
# zero ; zero
# nine ; nine
# one ; one
# eight ; eight
# one ; one
# over ; four
# five ; five
# minus ; minus
# two ; two
# nine ; nine
# eight ; eight
# times ; times
# five ; five
# nine ; nine
# seven ; seven
# minus ; minus
# nine ; nine
# one ; one
# one ; one
# plus ; plus
# two ; three
# minus ; minus
# six ; six
# three ; three
# nine ; nine
# four ; four
# eight ; eight
# minus ; minus
# nine ; nine
# three ; three
# plus ; six
# one ; one
# eight ; eight
# four ; four
# one ; one
# six ; six
# three ; three
# four ; four
# eight ; eight
# four ; four
# plus ; plus
# seven ; two
# nine ; nine
# three ; three
# six ; six
# minus ; minus
# seven ; seven
# one ; one
# three ; three
# times ; minus
# times ; nine
# six ; six
# over ; over
# four ; four
# eight ; eight
# nine ; nine
# minus ; minus
# eight ; eight
# eight ; eight
# times ; minus
# over ; over
# times ; times
# times ; plus
# one ; one
# one ; plus
# six ; six
# times ; times
# zero ; zero
# over ; over
# eight ; eight
# one ; one
# minus ; minus
# two ; two
# plus ; plus
# minus ; plus
# plus ; plus
# seven ; seven
# nine ; nine
# zero ; zero
# eight ; eight
# plus ; plus
# seven ; seven
# nine ; nine
# four ; four
# times ; times
# three ; three
# one ; one
# plus ; plus
# six ; six
# one ; one
# one ; one
# over ; over
# seven ; seven
# six ; eight
# eight ; eight
# nine ; nine
# nine ; nine
# five ; five
# times ; times
# seven ; seven
# over ; over
# plus ; plus
# times ; six
# two ; two
# one ; one
# two ; four
# six ; six
# times ; times
# five ; five
# four ; four
# times ; times
# minus ; minus
# minus ; minus
# five ; five
# six ; six
# five ; five
# eight ; eight
# zero ; zero
# zero ; zero
# five ; five
# one ; one
# four ; four
# plus ; plus
# one ; one
# zero ; zero
# times ; minus
# seven ; seven
# one ; one
# four ; four
# six ; six
# over ; over
# six ; six
# times ; times
# nine ; nine
# seven ; seven
# five ; five
# nine ; nine
# over ; over
# four ; four
# four ; four
# two ; two
# eight ; eight
# nine ; nine
# nine ; nine
# one ; four
# times ; times
# three ; three
# one ; one
# zero ; zero
# one ; one
# zero ; zero
# eight ; eight
# seven ; seven
# three ; three
# minus ; minus
# eight ; eight
# one ; one
# seven ; seven
# plus ; plus
# zero ; zero
# eight ; eight
# eight ; eight
# seven ; seven
# zero ; zero
# seven ; seven
# eight ; eight
# times ; times
# nine ; nine
# minus ; minus
# six ; six
# minus ; minus
# over ; over
# two ; two
# five ; five
# plus ; plus
# seven ; seven
# nine ; nine
# five ; five
# six ; six
# minus ; minus
# two ; two
# five ; times
# four ; four
# plus ; plus
# times ; minus
# nine ; nine
# minus ; minus
# eight ; eight
# zero ; zero
# nine ; nine
# plus ; plus
# nine ; nine
# three ; three
# minus ; minus
# three ; three
# nine ; nine
# eight ; eight
# eight ; eight
# times ; times
# eight ; eight
# one ; one
# seven ; seven
# three ; three
# over ; over
# seven ; seven
# five ; five
# 0.07654320987654321

# %% [markdown]
# # Record new data

# %%
import os
import sounddevice as sd
from scipy.io import wavfile 

freq = 44100
duration = 3

try:
    recording = sd.rec(int(duration * freq), samplerate=freq, channels=2)
    print("Recording: start speaking...")

    sd.wait()

    filepath = os.path.join(os.getcwd(), "..", "input", "input.wav")
    wavfile.write(filepath, freq, recording)  # Fix the function call

except Exception as e:
    print("An error occurred:", e)
# Out:
# Recording: start speaking...

# %% [markdown]
#     Example of classification pipeline

# %%
# Read new data and classify
net.eval()
with torch.no_grad():
    clip, sr = librosa.load(filepath)
    clip = librosa.resample(clip, orig_sr=sr, target_sr=8000)
    clip = librosa.to_mono(clip)
    clip = librosa.util.normalize(clip)
    clip = get_voiced_parts(clip,8000)
    clip = add_preemphasis_filter(clip)
    features_2d = get_2d_features(clip, 8000)
    features_2d = torch.Tensor(features_2d).view(-1,1,40,40).to(device)
    features_1d = torch.Tensor(get_1d_features(clip, 8000))
    features_1d = torch.unsqueeze(features_1d, dim = 0).to(device) #change the shape of the tensor
    out = net(features_2d, features_1d)
    classification = torch.argmax(out)

    out = out[0].detach().cpu().numpy()
    debug_ind = out.argsort()[::-1].astype('int')
print("{}; {}".format(np.array(labels)[debug_ind][:3], np.around(out[debug_ind][:3], decimals=3)))
# Out:
# ['four' 'zero' 'five']; [1. 0. 0.]

# %%
#hear the  snipped clip
sd.play(clip,8000)
sd.wait()
